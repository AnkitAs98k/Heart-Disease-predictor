# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitAs98k/Heart-Disease-predictor/blob/main/cropPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df1 = pd.read_csv('crop_yield.csv')
df2 = pd.read_csv('state_weather_data_1997_2020.csv')
df3 = pd.read_csv('state_soil_data.csv')

# %%
result1 = pd.merge(df1, df2, on='state', how='inner')
result1.head()
# Out:
#        crop  year_x       season  state     area  production  fertilizer  \
# 0  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 1  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 2  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 3  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 4  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
#
#    pesticide     yield  year_y  avg_temp_c  total_rainfall_mm  \
# 0   22882.34  0.796087    1997       22.41            1468.92
# 1   22882.34  0.796087    1998       22.98            1701.15
# 2   22882.34  0.796087    1999       23.26            1622.42
# 3   22882.34  0.796087    2000       22.37            1958.50
# 4   22882.34  0.796087    2001       22.72            1808.20
#
#    avg_humidity_percent
# 0                 70.71
# 1                 73.03
# 2                 71.99
# 3                 75.29
# 4                 74.66

# %%
df = pd.merge(result1,df3,on='state',how='inner')
df.head()
# Out:
#        crop  year_x       season  state     area  production  fertilizer  \
# 0  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 1  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 2  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 3  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
# 4  Arecanut    1997  Whole Year   Assam  73814.0       56708  7024878.38
#
#    pesticide     yield  year_y  avg_temp_c  total_rainfall_mm  \
# 0   22882.34  0.796087    1997       22.41            1468.92
# 1   22882.34  0.796087    1998       22.98            1701.15
# 2   22882.34  0.796087    1999       23.26            1622.42
# 3   22882.34  0.796087    2000       22.37            1958.50
# 4   22882.34  0.796087    2001       22.72            1808.20
#
#    avg_humidity_percent   N   P   K   pH
# 0                 70.71  60  18  38  5.8
# 1                 73.03  60  18  38  5.8
# ...

# %%
print(list(df.columns))
# Out:
# ['crop', 'year_x', 'season', 'state', 'area', 'production', 'fertilizer', 'pesticide', 'yield', 'year_y', 'avg_temp_c', 'total_rainfall_mm', 'avg_humidity_percent', 'N', 'P', 'K', 'pH']

# %%
sns.boxplot(df,)
